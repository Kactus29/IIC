# %% [markdown]
# # Imports

# %% [markdown]
# #### PyTorch

# %%
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
from torchvision import datasets
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import StepLR, OneCycleLR

# %%
print('PyTorch version', torch.__version__)
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print('Device:', device)
# Out:
# PyTorch version 2.5.1
# Device: cuda

# %% [markdown]
# #### General

# %%
import os
import json
import math
import time
import random
from pathlib import Path
import pandas as pd

import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

from tqdm import tqdm

from sklearn.metrics import roc_auc_score

# %% [markdown]
# #### Monai

# %%
from monai.losses import DiceLoss, FocalLoss

# %% [markdown]
# # Parameters

# %% [markdown]
# #### Directories for the images

# %%
parent = Path().cwd().parent
data_root = parent / 'try_1'

train_images_dir = data_root / 'train' / 'images'
train_masks_dir = data_root / 'train' / 'masks'

val_images_dir = data_root / 'val' / 'images'
val_masks_dir = data_root / 'val' / 'masks'

# %% [markdown]
# #### General parameters

# %%
IMG_HEIGHT = 768
IMG_WIDTH = 768

BATCH_SIZE = 4

EPOCHS = 300
print('Number of epochs:', EPOCHS)

LR = 0.0005
print('Learning rate:', LR)

"""
0 : background (black)
1 : arteries (white)
2 : veins (gray)
"""
NUM_CLASSES = 3

COLOR_TO_LABEL = {
    (0,0,0): 0,
    (255,255,255): 1,
    (128,128,128): 2
}
# Out:
# Number of epochs: 300
# Learning rate: 0.0005

# %% [markdown]
# # DataLoaders

# %% [markdown]
# #### Create the class for the dataset images

# %%
class RAVIRDataset(Dataset):
    def __init__(self, img_dir, mask_dir, img_size=(IMG_HEIGHT, IMG_WIDTH), transforms=None):
        self.img_paths = sorted(list(Path(img_dir).glob('*.png')))
        self.mask_dir = Path(mask_dir)
        self.img_size = img_size
        self.transforms = transforms

    def __len__(self):
        return len(self.img_paths)

    def __getitem__(self, idx):
        img_p = self.img_paths[idx]
        mask_p = self.mask_dir / img_p.name
        img = Image.open(img_p).convert('RGB').resize(self.img_size, Image.BILINEAR)
        img = np.array(img, dtype=np.float32) / 255.0
        img = np.transpose(img, (2,0,1))  # C,H,W
        img_t = torch.from_numpy(img).float()
        # load mask and map colors to labels
        m = Image.open(mask_p).convert('RGB').resize(self.img_size, Image.NEAREST)
        m_arr = np.array(m, dtype=np.uint8)
        label = np.zeros((self.img_size[1], self.img_size[0]), dtype=np.uint8)
        for color, lab in COLOR_TO_LABEL.items():
            mask = np.all(m_arr == np.array(color, dtype=np.uint8), axis=-1)
            label[mask] = lab
        label_t = torch.from_numpy(label).long()  # H,W
        return img_t, label_t

# %%
train_ds = RAVIRDataset(train_images_dir, train_masks_dir, (IMG_WIDTH, IMG_HEIGHT))
val_ds = RAVIRDataset(val_images_dir, val_masks_dir, (IMG_WIDTH, IMG_HEIGHT))

train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, num_workers=2)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, num_workers=2)

# %% [markdown]
# # U-Net model

# %%
class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.net = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.ReLU(inplace=True)
        )
    def forward(self, x):
        return self.net(x)

class UNet(nn.Module):
    def __init__(self, n_classes=NUM_CLASSES, in_channels=3, features=[32,64,128,256]):
        super().__init__()
        self.encs = nn.ModuleList()
        self.pools = nn.ModuleList()
        for f in features:
            self.encs.append(DoubleConv(in_channels, f))
            self.pools.append(nn.MaxPool2d(2))
            in_channels = f
        self.bottleneck = DoubleConv(features[-1], features[-1]*2)
        # decoder
        self.upconvs = nn.ModuleList()
        self.decs = nn.ModuleList()
        for f in reversed(features):
            self.upconvs.append(nn.ConvTranspose2d(f*2, f, kernel_size=2, stride=2))
            self.decs.append(DoubleConv(f*2, f))
        self.final_conv = nn.Conv2d(features[0], n_classes, kernel_size=1)

    def forward(self, x):
        skips = []
        for enc, pool in zip(self.encs, self.pools):
            x = enc(x)
            skips.append(x)
            x = pool(x)
        x = self.bottleneck(x)
        for up, dec, skip in zip(self.upconvs, self.decs, reversed(skips)):
            x = up(x)
            # pad if needed
            if x.shape != skip.shape:
                x = nn.functional.interpolate(x, size=skip.shape[2:])
            x = torch.cat([skip, x], dim=1)
            x = dec(x)
        x = self.final_conv(x)
        return x

model = UNet().to(device)
# print(model)

# %% [markdown]
# # Optimizer

# %%
optimizer = optim.AdamW(model.parameters(), lr=LR)

# %% [markdown]
# # Scheduler

# %%
scheduler = torch.optim.lr_scheduler.OneCycleLR(
    optimizer, 
    max_lr = 0.001,
    steps_per_epoch = len(train_loader),
    epochs = EPOCHS,
    pct_start = 0.3,
    anneal_strategy = "cos"
)

# %% [markdown]
# # Loss function

# %%
def dice_loss(outputs, targets, epsilon=1e-6):
    """
    outputs: logits (N, C, H, W)
    targets: labels (N, H, W)
    """
    # Probabilités
    probs = F.softmax(outputs, dim=1)

    N, C, H, W = probs.shape

    # One-hot du masque → shape (N, C, H, W)
    targets_onehot = F.one_hot(targets, num_classes=C).permute(0, 3, 1, 2).float()

    # On ignore la classe 0 (background)
    probs = probs[:, 1:, :, :]          # (N, C-1, H, W)
    targets_onehot = targets_onehot[:, 1:, :, :]  # (N, C-1, H, W)

    # Dice par classe
    intersection = torch.sum(probs * targets_onehot, dim=(0, 2, 3))
    cardinality  = torch.sum(probs + targets_onehot, dim=(0, 2, 3))

    dice_per_class = (2 * intersection + epsilon) / (cardinality + epsilon)

    # Loss = 1 - moyenne des dice des classes artery + vein
    return 1 - dice_per_class.mean()

# %%
percentage = [0.872, 0.054, 0.073]
inverse_percentage = [round((1/p),2) for p in percentage]
print(inverse_percentage)

weights = torch.tensor(inverse_percentage).to(device)
CE_loss = nn.CrossEntropyLoss(weight=weights)
# Out:
# [1.15, 18.52, 13.7]

# %%
def combined_loss(outputs, targets, alpha=0.5) :
    return alpha * CE_loss(outputs, targets) + (1-alpha) * dice_loss(outputs, targets)

# %% [markdown]
# # Model train

# %%
best_val_loss = float("inf")
best_val_dice = -float("inf")

model_name = "My_UNet_v3_new_loss_300epochs"
save_dir = Path("Models") / model_name

save_dir.mkdir(parents=True, exist_ok=True)
last_epoch_save = 0

# %%
NUM_CLASSES = 3
BACKGROUND_IDX = 0
VESSEL_CLASSES = [1, 2]

# %%
# ===========================================
#   DICTIONNAIRES STOCRAGE (MEAN ONLY)
# ===========================================

train_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        []
}

val_history = {
    "loss": [],
    "accuracy":   [],
    "dice":       [],
    "iou":        [],
    "precision":  [],
    "recall":     [],
    "sensitivity":[],
    "specificity":[],
    "auc":        []
}

# %%
# =========================
#          INIT
# =========================

def init_confmat_sums(num_classes=NUM_CLASSES) :
    sums = {
        "TP" : np.zeros(num_classes, dtype=np.int64),
        "FP" : np.zeros(num_classes, dtype=np.int64),
        "FN" : np.zeros(num_classes, dtype=np.int64),
        "TN" : np.zeros(num_classes, dtype=np.int64),
        "N"  : 0
    }
    return sums

def init_auc_buffers(include_classes=VESSEL_CLASSES) :
    return {c : {"y_true" : [], "y_score" : []} for c in include_classes}

# %%
# =========================
#         UPDATE
# =========================

def update_confmat_sums(sums, preds, targets, num_classes=NUM_CLASSES) :
    with torch.no_grad() :
        for c in range(num_classes) :
            p = (preds == c)
            t = (targets == c)
            tp = (p & t).sum().item()
            fp = (p & ~t).sum().item()
            fn = (~p & t).sum().item()
            tn = (~p & ~t).sum().item()
            sums["TP"][c] += tp
            sums["FP"][c] += fp
            sums["FN"][c] += fn
            sums["TN"][c] += tn
        sums["N"] += targets.numel()



def update_auc_buffers(buffers, logits, targets):
    with torch.no_grad():
        probs = F.softmax(logits, dim=1)
        flat_probs = probs.permute(0,2,3,1).reshape(-1, probs.shape[1])
        flat_t     = targets.reshape(-1)

        for c in buffers.keys():
            y_true = (flat_t == c).cpu().numpy().astype(np.uint8)
            y_score = flat_probs[:, c].cpu().numpy()
            buffers[c]["y_true"].append(y_true)
            buffers[c]["y_score"].append(y_score)

# %%
def compute_scalar_metrics_from_confmat(sums, include_classes):
    TP, FP, FN, TN = sums["TP"], sums["FP"], sums["FN"], sums["TN"]
    eps = 1e-7

    acc_c  = (TP + TN) / np.maximum(TP + TN + FP + FN, eps)
    prec_c = TP / np.maximum(TP + FP, eps)
    rec_c  = TP / np.maximum(TP + FN, eps)
    spec_c = TN / np.maximum(TN + FP, eps)
    dice_c = (2 * TP) / np.maximum(2 * TP + FP + FN, eps)
    iou_c  = TP / np.maximum(TP + FP + FN, eps)

    idx = np.array(include_classes, dtype=int)
    return {
        "accuracy":   float(np.mean(acc_c[idx])),
        "precision":  float(np.mean(prec_c[idx])),
        "recall":     float(np.mean(rec_c[idx])),
        "specificity":float(np.mean(spec_c[idx])),
        "dice":       float(np.mean(dice_c[idx])),
        "iou":        float(np.mean(iou_c[idx])),
    }

# %%
def compute_mean_auc(buffers):
    aucs = []
    for c, pack in buffers.items():
        if len(pack["y_true"]) == 0: 
            continue
        y_true = np.concatenate(pack["y_true"])
        y_score = np.concatenate(pack["y_score"])
        pos = (y_true == 1).sum()
        neg = (y_true == 0).sum()
        if pos == 0 or neg == 0:
            continue
        try:
            aucs.append(roc_auc_score(y_true, y_score))
        except:
            pass
    if len(aucs) == 0:
        return float("nan")
    return float(np.mean(aucs))

# %%
# =========================
#        LEARNING
# =========================

for epoch in range(EPOCHS) :

    # =========================
    #        TRAIN
    # =========================

    model.train()

    runing_loss = 0.0
    conf_sums = init_confmat_sums()
    auc_buf = init_auc_buffers()

    for imgs, masks in train_loader :

        imgs = imgs.to(device)
        masks = masks.to(device)

        optimizer.zero_grad()

        outputs = model(imgs)

        loss = combined_loss(outputs, masks)
        loss.backward()
        optimizer.step()
        scheduler.step()

        runing_loss += loss.item() * imgs.size(0)

        preds = outputs.argmax(dim=1)
        update_confmat_sums(conf_sums, preds, masks, NUM_CLASSES)
        update_auc_buffers(auc_buf, outputs, masks)
    
    train_loss = runing_loss / len(train_ds)
    train_metrics = compute_scalar_metrics_from_confmat(conf_sums, VESSEL_CLASSES)
    train_auc = compute_mean_auc(auc_buf)

    train_history["loss"].append(train_loss)
    train_history["accuracy"].append(train_metrics["accuracy"])
    train_history["dice"].append(train_metrics["dice"])
    train_history["iou"].append(train_metrics["iou"])
    train_history["precision"].append(train_metrics["precision"])
    train_history["recall"].append(train_metrics["recall"])
    train_history["specificity"].append(train_metrics["specificity"])
    train_history["auc"].append(train_auc)




    # =========================
    #       VALIDATION
    # =========================
    model.eval()

    val_runing_loss = 0.0
    conf_sums_val = init_confmat_sums()
    auc_buf_val   = init_auc_buffers()

    with torch.no_grad():
        for imgs, masks in val_loader:
            imgs  = imgs.to(device, non_blocking=True)
            masks = masks.to(device, non_blocking=True)

            outputs = model(imgs)
            loss = combined_loss(outputs, masks)
            val_runing_loss += loss.item() * imgs.size(0)

            preds = outputs.argmax(dim=1)
            update_confmat_sums(conf_sums_val, preds, masks, NUM_CLASSES)
            update_auc_buffers(auc_buf_val, outputs, masks)

    val_loss = val_runing_loss / len(val_ds)
    val_metrics = compute_scalar_metrics_from_confmat(conf_sums_val, VESSEL_CLASSES)
    val_auc = compute_mean_auc(auc_buf_val)

    val_history["loss"].append(val_loss)
    val_history["accuracy"].append(val_metrics["accuracy"])
    val_history["dice"].append(val_metrics["dice"])
    val_history["iou"].append(val_metrics["iou"])
    val_history["precision"].append(val_metrics["precision"])
    val_history["recall"].append(val_metrics["recall"])
    val_history["specificity"].append(val_metrics["specificity"])
    val_history["auc"].append(val_auc)




    # =========================
    #           LOGS
    # =========================
    print('-'*30)
    print(f"Epoch {epoch+1}/{EPOCHS}")
    print(f"  Train Loss: {train_loss:.4f} | Dice: {train_metrics['dice']:.4f} | IoU: {train_metrics['iou']:.4f}")
    print(f"  Val   Loss: {val_loss:.4f} | Dice: {val_metrics['dice']:.4f} | IoU: {val_metrics['iou']:.4f}")




    # =========================
    #     SAVE BEST MODEL
    # =========================
    if val_loss < best_val_loss:
        best_val_loss = val_loss
        torch.save(model.state_dict(), str(save_dir / "loss_best_model_state_dict.pth"))
        torch.save(model, str(save_dir / "loss_best_model_full.pth"))
        print(f"✅ Nouveau meilleur modèle loss sauvegardé")
    
    val_dice = val_metrics["dice"]
    if val_dice > best_val_dice :
        best_val_dice = val_dice
        torch.save(model.state_dict(), str(save_dir / "dice_best_model_state_dict.pth"))
        torch.save(model, str(save_dir / "dice_best_model_full.pth"))
        print(f"✅ Nouveau meilleur modèle dice sauvegardé")



# =========================
#     SAVE LAST MODEL
# =========================
torch.save(model.state_dict(), str(save_dir / f"epoch{EPOCHS}_model_state_dict.pth"))
torch.save(model, str(save_dir / f"epoch{EPOCHS}_model_full.pth"))
# Out:
# ------------------------------
# Epoch 1/300
#   Train Loss: 1.0004 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9990 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 2/300
#   Train Loss: 0.9999 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9986 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 3/300
#   Train Loss: 0.9995 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9983 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 4/300
#   Train Loss: 0.9991 | Dice: 0.0506 | IoU: 0.0266
#   Val   Loss: 0.9980 | Dice: 0.0557 | IoU: 0.0295
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 5/300
#   Train Loss: 0.9986 | Dice: 0.0508 | IoU: 0.0267
#   Val   Loss: 0.9976 | Dice: 0.0576 | IoU: 0.0306
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 6/300
#   Train Loss: 0.9982 | Dice: 0.0552 | IoU: 0.0292
#   Val   Loss: 0.9973 | Dice: 0.0652 | IoU: 0.0349
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 7/300
#   Train Loss: 0.9976 | Dice: 0.0643 | IoU: 0.0344
#   Val   Loss: 0.9969 | Dice: 0.0938 | IoU: 0.0517
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 8/300
#   Train Loss: 0.9970 | Dice: 0.0541 | IoU: 0.0286
#   Val   Loss: 0.9963 | Dice: 0.0259 | IoU: 0.0133
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 9/300
#   Train Loss: 0.9962 | Dice: 0.0106 | IoU: 0.0054
#   Val   Loss: 0.9957 | Dice: 0.0036 | IoU: 0.0018
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 10/300
#   Train Loss: 0.9953 | Dice: 0.0261 | IoU: 0.0133
#   Val   Loss: 0.9948 | Dice: 0.0990 | IoU: 0.0547
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 11/300
#   Train Loss: 0.9940 | Dice: 0.0868 | IoU: 0.0473
#   Val   Loss: 0.9938 | Dice: 0.0657 | IoU: 0.0351
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 12/300
#   Train Loss: 0.9924 | Dice: 0.0708 | IoU: 0.0380
#   Val   Loss: 0.9925 | Dice: 0.0642 | IoU: 0.0343
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 13/300
#   Train Loss: 0.9903 | Dice: 0.0696 | IoU: 0.0374
#   Val   Loss: 0.9908 | Dice: 0.0640 | IoU: 0.0342
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 14/300
#   Train Loss: 0.9874 | Dice: 0.0695 | IoU: 0.0374
#   Val   Loss: 0.9885 | Dice: 0.0640 | IoU: 0.0342
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 15/300
#   Train Loss: 0.9819 | Dice: 0.0695 | IoU: 0.0374
#   Val   Loss: 0.9910 | Dice: 0.0640 | IoU: 0.0342
# ------------------------------
# Epoch 16/300
#   Train Loss: 0.9804 | Dice: 0.0695 | IoU: 0.0374
#   Val   Loss: 0.9874 | Dice: 0.0640 | IoU: 0.0342
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 17/300
#   Train Loss: 0.9779 | Dice: 0.0695 | IoU: 0.0374
#   Val   Loss: 0.9845 | Dice: 0.0641 | IoU: 0.0342
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 18/300
#   Train Loss: 0.9760 | Dice: 0.0696 | IoU: 0.0374
#   Val   Loss: 0.9824 | Dice: 0.0641 | IoU: 0.0343
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 19/300
#   Train Loss: 0.9711 | Dice: 0.0696 | IoU: 0.0374
#   Val   Loss: 0.9810 | Dice: 0.0641 | IoU: 0.0342
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 20/300
#   Train Loss: 0.9660 | Dice: 0.0702 | IoU: 0.0378
#   Val   Loss: 0.9732 | Dice: 0.0717 | IoU: 0.0386
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 21/300
#   Train Loss: 0.9576 | Dice: 0.0846 | IoU: 0.0462
#   Val   Loss: 0.9654 | Dice: 0.0857 | IoU: 0.0469
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 22/300
#   Train Loss: 0.9542 | Dice: 0.0986 | IoU: 0.0547
#   Val   Loss: 0.9605 | Dice: 0.0956 | IoU: 0.0529
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 23/300
#   Train Loss: 0.9516 | Dice: 0.1081 | IoU: 0.0606
#   Val   Loss: 0.9556 | Dice: 0.1092 | IoU: 0.0613
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 24/300
#   Train Loss: 0.9482 | Dice: 0.1068 | IoU: 0.0598
#   Val   Loss: 0.9504 | Dice: 0.0979 | IoU: 0.0543
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 25/300
#   Train Loss: 0.9415 | Dice: 0.1057 | IoU: 0.0591
#   Val   Loss: 0.9452 | Dice: 0.1052 | IoU: 0.0588
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 26/300
#   Train Loss: 0.9408 | Dice: 0.1170 | IoU: 0.0663
#   Val   Loss: 0.9433 | Dice: 0.0913 | IoU: 0.0502
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 27/300
#   Train Loss: 0.9269 | Dice: 0.1110 | IoU: 0.0624
#   Val   Loss: 0.9267 | Dice: 0.1024 | IoU: 0.0570
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 28/300
#   Train Loss: 0.9216 | Dice: 0.1118 | IoU: 0.0629
#   Val   Loss: 0.9302 | Dice: 0.1842 | IoU: 0.1129
# ------------------------------
# Epoch 29/300
#   Train Loss: 0.9235 | Dice: 0.1211 | IoU: 0.0689
#   Val   Loss: 0.8984 | Dice: 0.1732 | IoU: 0.1047
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 30/300
#   Train Loss: 0.8995 | Dice: 0.1278 | IoU: 0.0733
#   Val   Loss: 0.8890 | Dice: 0.1898 | IoU: 0.1171
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 31/300
#   Train Loss: 0.8988 | Dice: 0.1299 | IoU: 0.0746
#   Val   Loss: 0.9310 | Dice: 0.1971 | IoU: 0.1227
# ------------------------------
# Epoch 32/300
#   Train Loss: 0.9212 | Dice: 0.1516 | IoU: 0.0893
#   Val   Loss: 0.8812 | Dice: 0.1464 | IoU: 0.0857
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 33/300
#   Train Loss: 0.9055 | Dice: 0.1362 | IoU: 0.0788
#   Val   Loss: 0.8762 | Dice: 0.1747 | IoU: 0.1058
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 34/300
#   Train Loss: 0.8859 | Dice: 0.1409 | IoU: 0.0819
#   Val   Loss: 0.8933 | Dice: 0.1312 | IoU: 0.0743
# ------------------------------
# Epoch 35/300
#   Train Loss: 0.8828 | Dice: 0.1394 | IoU: 0.0805
#   Val   Loss: 0.8664 | Dice: 0.2095 | IoU: 0.1325
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 36/300
#   Train Loss: 0.8832 | Dice: 0.1414 | IoU: 0.0823
#   Val   Loss: 0.8904 | Dice: 0.1912 | IoU: 0.1182
# ------------------------------
# Epoch 37/300
#   Train Loss: 0.8747 | Dice: 0.1434 | IoU: 0.0837
#   Val   Loss: 0.8699 | Dice: 0.2038 | IoU: 0.1280
# ------------------------------
# Epoch 38/300
#   Train Loss: 0.8573 | Dice: 0.1717 | IoU: 0.1019
#   Val   Loss: 0.8593 | Dice: 0.2024 | IoU: 0.1210
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 39/300
#   Train Loss: 0.8460 | Dice: 0.2141 | IoU: 0.1272
#   Val   Loss: 0.8441 | Dice: 0.2074 | IoU: 0.1274
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 40/300
#   Train Loss: 0.8400 | Dice: 0.1865 | IoU: 0.1126
#   Val   Loss: 0.8934 | Dice: 0.1486 | IoU: 0.0872
# ------------------------------
# Epoch 41/300
#   Train Loss: 0.9436 | Dice: 0.1559 | IoU: 0.0901
#   Val   Loss: 1.0330 | Dice: 0.2144 | IoU: 0.1321
# ------------------------------
# Epoch 42/300
#   Train Loss: 0.9317 | Dice: 0.1804 | IoU: 0.1019
#   Val   Loss: 0.8934 | Dice: 0.1567 | IoU: 0.0879
# ------------------------------
# Epoch 43/300
#   Train Loss: 0.8932 | Dice: 0.1797 | IoU: 0.1024
#   Val   Loss: 0.8828 | Dice: 0.2206 | IoU: 0.1278
# ------------------------------
# Epoch 44/300
#   Train Loss: 0.8756 | Dice: 0.2104 | IoU: 0.1203
#   Val   Loss: 0.8867 | Dice: 0.2177 | IoU: 0.1272
# ------------------------------
# Epoch 45/300
#   Train Loss: 0.8695 | Dice: 0.2127 | IoU: 0.1231
#   Val   Loss: 0.8653 | Dice: 0.1885 | IoU: 0.1113
# ------------------------------
# Epoch 46/300
#   Train Loss: 0.8502 | Dice: 0.1934 | IoU: 0.1178
#   Val   Loss: 0.8574 | Dice: 0.1738 | IoU: 0.1052
# ------------------------------
# Epoch 47/300
#   Train Loss: 0.8333 | Dice: 0.1851 | IoU: 0.1118
#   Val   Loss: 0.8794 | Dice: 0.2504 | IoU: 0.1607
# ------------------------------
# Epoch 48/300
#   Train Loss: 0.9404 | Dice: 0.1747 | IoU: 0.1024
#   Val   Loss: 0.9651 | Dice: 0.2047 | IoU: 0.1276
# ------------------------------
# Epoch 49/300
#   Train Loss: 0.9838 | Dice: 0.1464 | IoU: 0.0836
#   Val   Loss: 0.9383 | Dice: 0.1376 | IoU: 0.0786
# ------------------------------
# Epoch 50/300
#   Train Loss: 0.9353 | Dice: 0.1300 | IoU: 0.0736
#   Val   Loss: 0.9469 | Dice: 0.1061 | IoU: 0.0579
# ------------------------------
# Epoch 51/300
#   Train Loss: 0.9321 | Dice: 0.1393 | IoU: 0.0765
#   Val   Loss: 0.9376 | Dice: 0.1386 | IoU: 0.0761
# ------------------------------
# Epoch 52/300
#   Train Loss: 0.9250 | Dice: 0.1474 | IoU: 0.0814
#   Val   Loss: 0.9355 | Dice: 0.1593 | IoU: 0.0916
# ------------------------------
# Epoch 53/300
#   Train Loss: 0.9161 | Dice: 0.1327 | IoU: 0.0749
#   Val   Loss: 0.9624 | Dice: 0.1852 | IoU: 0.1136
# ------------------------------
# Epoch 54/300
#   Train Loss: 0.9527 | Dice: 0.1288 | IoU: 0.0714
#   Val   Loss: 0.9293 | Dice: 0.1288 | IoU: 0.0720
# ------------------------------
# Epoch 55/300
#   Train Loss: 0.9377 | Dice: 0.1230 | IoU: 0.0697
#   Val   Loss: 0.9369 | Dice: 0.1249 | IoU: 0.0713
# ------------------------------
# Epoch 56/300
#   Train Loss: 0.9327 | Dice: 0.1084 | IoU: 0.0608
#   Val   Loss: 0.9429 | Dice: 0.0956 | IoU: 0.0528
# ------------------------------
# Epoch 57/300
#   Train Loss: 0.9273 | Dice: 0.1104 | IoU: 0.0620
#   Val   Loss: 0.9380 | Dice: 0.1200 | IoU: 0.0682
# ------------------------------
# Epoch 58/300
#   Train Loss: 0.9276 | Dice: 0.1235 | IoU: 0.0704
#   Val   Loss: 0.9374 | Dice: 0.1072 | IoU: 0.0600
# ------------------------------
# Epoch 59/300
#   Train Loss: 0.9248 | Dice: 0.1070 | IoU: 0.0599
#   Val   Loss: 0.9353 | Dice: 0.1132 | IoU: 0.0638
# ------------------------------
# Epoch 60/300
#   Train Loss: 0.9196 | Dice: 0.1235 | IoU: 0.0704
#   Val   Loss: 0.9058 | Dice: 0.1281 | IoU: 0.0735
# ------------------------------
# Epoch 61/300
#   Train Loss: 1.0015 | Dice: 0.0820 | IoU: 0.0446
#   Val   Loss: 1.0102 | Dice: 0.0640 | IoU: 0.0342
# ------------------------------
# Epoch 62/300
#   Train Loss: 0.9535 | Dice: 0.0893 | IoU: 0.0490
#   Val   Loss: 0.9647 | Dice: 0.1549 | IoU: 0.0916
# ------------------------------
# Epoch 63/300
#   Train Loss: 0.9560 | Dice: 0.1284 | IoU: 0.0736
#   Val   Loss: 0.9507 | Dice: 0.1110 | IoU: 0.0624
# ------------------------------
# Epoch 64/300
#   Train Loss: 0.9356 | Dice: 0.1054 | IoU: 0.0589
#   Val   Loss: 0.9522 | Dice: 0.0925 | IoU: 0.0510
# ------------------------------
# Epoch 65/300
#   Train Loss: 0.9305 | Dice: 0.1100 | IoU: 0.0618
#   Val   Loss: 0.9399 | Dice: 0.1159 | IoU: 0.0655
# ------------------------------
# Epoch 66/300
#   Train Loss: 0.9249 | Dice: 0.1140 | IoU: 0.0644
#   Val   Loss: 0.9380 | Dice: 0.0990 | IoU: 0.0549
# ------------------------------
# Epoch 67/300
#   Train Loss: 0.9253 | Dice: 0.1050 | IoU: 0.0587
#   Val   Loss: 0.9330 | Dice: 0.1147 | IoU: 0.0648
# ------------------------------
# Epoch 68/300
#   Train Loss: 0.9280 | Dice: 0.1244 | IoU: 0.0711
#   Val   Loss: 0.9300 | Dice: 0.1121 | IoU: 0.0631
# ------------------------------
# Epoch 69/300
#   Train Loss: 0.9267 | Dice: 0.1032 | IoU: 0.0575
#   Val   Loss: 0.9298 | Dice: 0.1180 | IoU: 0.0669
# ------------------------------
# Epoch 70/300
#   Train Loss: 0.9192 | Dice: 0.1271 | IoU: 0.0728
#   Val   Loss: 0.9303 | Dice: 0.1250 | IoU: 0.0714
# ------------------------------
# Epoch 71/300
#   Train Loss: 0.9135 | Dice: 0.1233 | IoU: 0.0703
#   Val   Loss: 0.9340 | Dice: 0.1012 | IoU: 0.0563
# ------------------------------
# Epoch 72/300
#   Train Loss: 0.9131 | Dice: 0.1201 | IoU: 0.0682
#   Val   Loss: 0.9257 | Dice: 0.1260 | IoU: 0.0721
# ------------------------------
# Epoch 73/300
#   Train Loss: 0.9066 | Dice: 0.1226 | IoU: 0.0699
#   Val   Loss: 0.9205 | Dice: 0.1113 | IoU: 0.0626
# ------------------------------
# Epoch 74/300
#   Train Loss: 0.9124 | Dice: 0.1210 | IoU: 0.0688
#   Val   Loss: 0.9303 | Dice: 0.1022 | IoU: 0.0569
# ------------------------------
# Epoch 75/300
#   Train Loss: 0.9259 | Dice: 0.1227 | IoU: 0.0699
#   Val   Loss: 0.9500 | Dice: 0.0751 | IoU: 0.0406
# ------------------------------
# Epoch 76/300
#   Train Loss: 0.9184 | Dice: 0.1122 | IoU: 0.0632
#   Val   Loss: 0.9282 | Dice: 0.1406 | IoU: 0.0818
# ------------------------------
# Epoch 77/300
#   Train Loss: 0.9064 | Dice: 0.1345 | IoU: 0.0768
#   Val   Loss: 0.9258 | Dice: 0.1126 | IoU: 0.0630
# ------------------------------
# Epoch 78/300
#   Train Loss: 0.9046 | Dice: 0.1277 | IoU: 0.0728
#   Val   Loss: 0.9154 | Dice: 0.1359 | IoU: 0.0785
# ------------------------------
# Epoch 79/300
#   Train Loss: 0.9030 | Dice: 0.1447 | IoU: 0.0815
#   Val   Loss: 0.9307 | Dice: 0.1576 | IoU: 0.0934
# ------------------------------
# Epoch 80/300
#   Train Loss: 0.9105 | Dice: 0.1312 | IoU: 0.0737
#   Val   Loss: 0.9278 | Dice: 0.1630 | IoU: 0.0973
# ------------------------------
# Epoch 81/300
#   Train Loss: 0.8997 | Dice: 0.1712 | IoU: 0.0989
#   Val   Loss: 0.9738 | Dice: 0.0962 | IoU: 0.0520
# ------------------------------
# Epoch 82/300
#   Train Loss: 0.9324 | Dice: 0.1196 | IoU: 0.0666
#   Val   Loss: 0.9380 | Dice: 0.1589 | IoU: 0.0938
# ------------------------------
# Epoch 83/300
#   Train Loss: 0.9040 | Dice: 0.1416 | IoU: 0.0800
#   Val   Loss: 0.9412 | Dice: 0.1003 | IoU: 0.0550
# ------------------------------
# Epoch 84/300
#   Train Loss: 0.9052 | Dice: 0.1259 | IoU: 0.0711
#   Val   Loss: 0.9173 | Dice: 0.1472 | IoU: 0.0862
# ------------------------------
# Epoch 85/300
#   Train Loss: 0.9006 | Dice: 0.1344 | IoU: 0.0764
#   Val   Loss: 0.9096 | Dice: 0.1444 | IoU: 0.0805
# ------------------------------
# Epoch 86/300
#   Train Loss: 0.8856 | Dice: 0.1828 | IoU: 0.1043
#   Val   Loss: 0.8952 | Dice: 0.1957 | IoU: 0.1108
# ------------------------------
# Epoch 87/300
#   Train Loss: 0.8737 | Dice: 0.2105 | IoU: 0.1191
#   Val   Loss: 0.9351 | Dice: 0.1933 | IoU: 0.1182
# ------------------------------
# Epoch 88/300
#   Train Loss: 0.9040 | Dice: 0.1594 | IoU: 0.0917
#   Val   Loss: 0.8974 | Dice: 0.2246 | IoU: 0.1339
# ------------------------------
# Epoch 89/300
#   Train Loss: 0.8849 | Dice: 0.2167 | IoU: 0.1236
#   Val   Loss: 0.8995 | Dice: 0.1839 | IoU: 0.1044
# ------------------------------
# Epoch 90/300
#   Train Loss: 0.8818 | Dice: 0.1989 | IoU: 0.1126
#   Val   Loss: 0.8887 | Dice: 0.2066 | IoU: 0.1215
# ------------------------------
# Epoch 91/300
#   Train Loss: 0.8728 | Dice: 0.2171 | IoU: 0.1251
#   Val   Loss: 0.8850 | Dice: 0.1848 | IoU: 0.1043
# ------------------------------
# Epoch 92/300
#   Train Loss: 0.8626 | Dice: 0.1799 | IoU: 0.1038
#   Val   Loss: 0.9219 | Dice: 0.2270 | IoU: 0.1381
# ------------------------------
# Epoch 93/300
#   Train Loss: 0.8913 | Dice: 0.2217 | IoU: 0.1273
#   Val   Loss: 0.9012 | Dice: 0.1955 | IoU: 0.1099
# ------------------------------
# Epoch 94/300
#   Train Loss: 0.8958 | Dice: 0.2120 | IoU: 0.1215
#   Val   Loss: 0.8989 | Dice: 0.1692 | IoU: 0.0944
# ------------------------------
# Epoch 95/300
#   Train Loss: 0.8713 | Dice: 0.1935 | IoU: 0.1104
#   Val   Loss: 0.9070 | Dice: 0.1641 | IoU: 0.0949
# ------------------------------
# Epoch 96/300
#   Train Loss: 0.8689 | Dice: 0.2008 | IoU: 0.1166
#   Val   Loss: 0.9057 | Dice: 0.1657 | IoU: 0.0921
# ------------------------------
# Epoch 97/300
#   Train Loss: 0.8666 | Dice: 0.2135 | IoU: 0.1228
#   Val   Loss: 0.8842 | Dice: 0.1587 | IoU: 0.0892
# ------------------------------
# Epoch 98/300
#   Train Loss: 0.8485 | Dice: 0.1793 | IoU: 0.1030
#   Val   Loss: 0.8509 | Dice: 0.2398 | IoU: 0.1476
# ------------------------------
# Epoch 99/300
#   Train Loss: 0.8287 | Dice: 0.2292 | IoU: 0.1352
#   Val   Loss: 0.8971 | Dice: 0.2374 | IoU: 0.1450
# ------------------------------
# Epoch 100/300
#   Train Loss: 0.8522 | Dice: 0.2426 | IoU: 0.1419
#   Val   Loss: 0.8388 | Dice: 0.2565 | IoU: 0.1530
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 101/300
#   Train Loss: 0.8217 | Dice: 0.2538 | IoU: 0.1485
#   Val   Loss: 0.8443 | Dice: 0.2174 | IoU: 0.1300
# ------------------------------
# Epoch 102/300
#   Train Loss: 0.8075 | Dice: 0.2481 | IoU: 0.1472
#   Val   Loss: 0.8458 | Dice: 0.3520 | IoU: 0.2193
# ------------------------------
# Epoch 103/300
#   Train Loss: 0.8821 | Dice: 0.2833 | IoU: 0.1729
#   Val   Loss: 0.9102 | Dice: 0.1821 | IoU: 0.1024
# ------------------------------
# Epoch 104/300
#   Train Loss: 0.8741 | Dice: 0.1937 | IoU: 0.1098
#   Val   Loss: 0.8824 | Dice: 0.2565 | IoU: 0.1609
# ------------------------------
# Epoch 105/300
#   Train Loss: 0.8670 | Dice: 0.2088 | IoU: 0.1220
#   Val   Loss: 0.8825 | Dice: 0.2867 | IoU: 0.1712
# ------------------------------
# Epoch 106/300
#   Train Loss: 0.8589 | Dice: 0.2446 | IoU: 0.1410
#   Val   Loss: 0.8714 | Dice: 0.1999 | IoU: 0.1182
# ------------------------------
# Epoch 107/300
#   Train Loss: 0.8498 | Dice: 0.1801 | IoU: 0.1061
#   Val   Loss: 0.8380 | Dice: 0.1998 | IoU: 0.1245
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 108/300
#   Train Loss: 0.8362 | Dice: 0.2088 | IoU: 0.1242
#   Val   Loss: 0.8269 | Dice: 0.2770 | IoU: 0.1683
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 109/300
#   Train Loss: 0.8292 | Dice: 0.2653 | IoU: 0.1556
#   Val   Loss: 0.8379 | Dice: 0.2885 | IoU: 0.1743
# ------------------------------
# Epoch 110/300
#   Train Loss: 0.8348 | Dice: 0.2865 | IoU: 0.1685
#   Val   Loss: 0.8705 | Dice: 0.2304 | IoU: 0.1331
# ------------------------------
# Epoch 111/300
#   Train Loss: 0.8363 | Dice: 0.2722 | IoU: 0.1610
#   Val   Loss: 0.8614 | Dice: 0.1858 | IoU: 0.1083
# ------------------------------
# Epoch 112/300
#   Train Loss: 0.8396 | Dice: 0.1962 | IoU: 0.1141
#   Val   Loss: 0.8411 | Dice: 0.2339 | IoU: 0.1387
# ------------------------------
# Epoch 113/300
#   Train Loss: 0.8126 | Dice: 0.2711 | IoU: 0.1621
#   Val   Loss: 0.8309 | Dice: 0.2420 | IoU: 0.1436
# ------------------------------
# Epoch 114/300
#   Train Loss: 0.8226 | Dice: 0.2413 | IoU: 0.1410
#   Val   Loss: 0.7974 | Dice: 0.3254 | IoU: 0.2025
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 115/300
#   Train Loss: 0.8051 | Dice: 0.3060 | IoU: 0.1875
#   Val   Loss: 0.8690 | Dice: 0.1983 | IoU: 0.1132
# ------------------------------
# Epoch 116/300
#   Train Loss: 0.8226 | Dice: 0.2456 | IoU: 0.1431
#   Val   Loss: 0.8064 | Dice: 0.3080 | IoU: 0.1889
# ------------------------------
# Epoch 117/300
#   Train Loss: 0.8038 | Dice: 0.2889 | IoU: 0.1735
#   Val   Loss: 0.8192 | Dice: 0.2368 | IoU: 0.1412
# ------------------------------
# Epoch 118/300
#   Train Loss: 0.7841 | Dice: 0.2610 | IoU: 0.1557
#   Val   Loss: 0.8148 | Dice: 0.2503 | IoU: 0.1501
# ------------------------------
# Epoch 119/300
#   Train Loss: 0.7707 | Dice: 0.2960 | IoU: 0.1778
#   Val   Loss: 0.7917 | Dice: 0.3398 | IoU: 0.2129
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 120/300
#   Train Loss: 0.7932 | Dice: 0.3039 | IoU: 0.1821
#   Val   Loss: 0.7786 | Dice: 0.3316 | IoU: 0.2049
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 121/300
#   Train Loss: 0.8082 | Dice: 0.2564 | IoU: 0.1537
#   Val   Loss: 0.9613 | Dice: 0.3221 | IoU: 0.1998
# ------------------------------
# Epoch 122/300
#   Train Loss: 0.9076 | Dice: 0.2375 | IoU: 0.1387
#   Val   Loss: 0.8768 | Dice: 0.2285 | IoU: 0.1312
# ------------------------------
# Epoch 123/300
#   Train Loss: 0.8784 | Dice: 0.2411 | IoU: 0.1404
#   Val   Loss: 0.9106 | Dice: 0.1601 | IoU: 0.0895
# ------------------------------
# Epoch 124/300
#   Train Loss: 0.8678 | Dice: 0.2198 | IoU: 0.1269
#   Val   Loss: 0.9084 | Dice: 0.1765 | IoU: 0.0983
# ------------------------------
# Epoch 125/300
#   Train Loss: 0.8505 | Dice: 0.2309 | IoU: 0.1325
#   Val   Loss: 0.8539 | Dice: 0.2599 | IoU: 0.1531
# ------------------------------
# Epoch 126/300
#   Train Loss: 0.8277 | Dice: 0.2650 | IoU: 0.1538
#   Val   Loss: 0.8293 | Dice: 0.2616 | IoU: 0.1537
# ------------------------------
# Epoch 127/300
#   Train Loss: 0.8047 | Dice: 0.3032 | IoU: 0.1818
#   Val   Loss: 0.8356 | Dice: 0.2285 | IoU: 0.1325
# ------------------------------
# Epoch 128/300
#   Train Loss: 0.7892 | Dice: 0.2633 | IoU: 0.1553
#   Val   Loss: 0.8457 | Dice: 0.3295 | IoU: 0.2063
# ------------------------------
# Epoch 129/300
#   Train Loss: 0.8357 | Dice: 0.2528 | IoU: 0.1518
#   Val   Loss: 0.8575 | Dice: 0.2329 | IoU: 0.1357
# ------------------------------
# Epoch 130/300
#   Train Loss: 0.8070 | Dice: 0.2662 | IoU: 0.1560
#   Val   Loss: 0.8358 | Dice: 0.2769 | IoU: 0.1668
# ------------------------------
# Epoch 131/300
#   Train Loss: 0.7955 | Dice: 0.2866 | IoU: 0.1734
#   Val   Loss: 0.8250 | Dice: 0.2882 | IoU: 0.1751
# ------------------------------
# Epoch 132/300
#   Train Loss: 0.7948 | Dice: 0.3434 | IoU: 0.2147
#   Val   Loss: 0.8378 | Dice: 0.2342 | IoU: 0.1368
# ------------------------------
# Epoch 133/300
#   Train Loss: 0.7994 | Dice: 0.2658 | IoU: 0.1571
#   Val   Loss: 0.8295 | Dice: 0.3301 | IoU: 0.2032
# ------------------------------
# Epoch 134/300
#   Train Loss: 0.7668 | Dice: 0.3467 | IoU: 0.2158
#   Val   Loss: 0.7817 | Dice: 0.2963 | IoU: 0.1801
# ------------------------------
# Epoch 135/300
#   Train Loss: 0.7551 | Dice: 0.3253 | IoU: 0.2009
#   Val   Loss: 0.7825 | Dice: 0.3355 | IoU: 0.2080
# ------------------------------
# Epoch 136/300
#   Train Loss: 0.7471 | Dice: 0.3405 | IoU: 0.2097
#   Val   Loss: 0.7761 | Dice: 0.3376 | IoU: 0.2086
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 137/300
#   Train Loss: 0.7526 | Dice: 0.3458 | IoU: 0.2145
#   Val   Loss: 0.7920 | Dice: 0.3230 | IoU: 0.1967
# ------------------------------
# Epoch 138/300
#   Train Loss: 0.7330 | Dice: 0.3766 | IoU: 0.2367
#   Val   Loss: 0.7848 | Dice: 0.3349 | IoU: 0.2088
# ------------------------------
# Epoch 139/300
#   Train Loss: 0.7324 | Dice: 0.3695 | IoU: 0.2334
#   Val   Loss: 0.7634 | Dice: 0.3644 | IoU: 0.2263
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 140/300
#   Train Loss: 0.7273 | Dice: 0.3610 | IoU: 0.2259
#   Val   Loss: 0.8277 | Dice: 0.3862 | IoU: 0.2436
# ------------------------------
# Epoch 141/300
#   Train Loss: 0.7654 | Dice: 0.3502 | IoU: 0.2174
#   Val   Loss: 0.7582 | Dice: 0.3522 | IoU: 0.2186
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 142/300
#   Train Loss: 0.7411 | Dice: 0.3770 | IoU: 0.2376
#   Val   Loss: 0.8711 | Dice: 0.2776 | IoU: 0.1676
# ------------------------------
# Epoch 143/300
#   Train Loss: 0.7675 | Dice: 0.3343 | IoU: 0.2055
#   Val   Loss: 0.7642 | Dice: 0.3667 | IoU: 0.2272
# ------------------------------
# Epoch 144/300
#   Train Loss: 0.7379 | Dice: 0.4097 | IoU: 0.2618
#   Val   Loss: 0.7700 | Dice: 0.3246 | IoU: 0.2007
# ------------------------------
# Epoch 145/300
#   Train Loss: 0.7318 | Dice: 0.3587 | IoU: 0.2262
#   Val   Loss: 0.7675 | Dice: 0.3601 | IoU: 0.2256
# ------------------------------
# Epoch 146/300
#   Train Loss: 0.7246 | Dice: 0.3928 | IoU: 0.2499
#   Val   Loss: 0.7717 | Dice: 0.3374 | IoU: 0.2094
# ------------------------------
# Epoch 147/300
#   Train Loss: 0.7229 | Dice: 0.3737 | IoU: 0.2362
#   Val   Loss: 0.7635 | Dice: 0.3991 | IoU: 0.2532
# ------------------------------
# Epoch 148/300
#   Train Loss: 0.7249 | Dice: 0.4040 | IoU: 0.2591
#   Val   Loss: 0.7514 | Dice: 0.3597 | IoU: 0.2261
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 149/300
#   Train Loss: 0.7171 | Dice: 0.3808 | IoU: 0.2417
#   Val   Loss: 0.7423 | Dice: 0.3834 | IoU: 0.2423
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 150/300
#   Train Loss: 0.7130 | Dice: 0.4055 | IoU: 0.2603
#   Val   Loss: 0.7721 | Dice: 0.3321 | IoU: 0.2063
# ------------------------------
# Epoch 151/300
#   Train Loss: 0.7054 | Dice: 0.4029 | IoU: 0.2585
#   Val   Loss: 0.7387 | Dice: 0.4078 | IoU: 0.2595
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 152/300
#   Train Loss: 0.7151 | Dice: 0.4071 | IoU: 0.2615
#   Val   Loss: 0.7631 | Dice: 0.3403 | IoU: 0.2107
# ------------------------------
# Epoch 153/300
#   Train Loss: 0.7090 | Dice: 0.3919 | IoU: 0.2466
#   Val   Loss: 0.7287 | Dice: 0.3842 | IoU: 0.2438
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 154/300
#   Train Loss: 0.7060 | Dice: 0.3862 | IoU: 0.2471
#   Val   Loss: 0.7972 | Dice: 0.3896 | IoU: 0.2459
# ------------------------------
# Epoch 155/300
#   Train Loss: 0.7167 | Dice: 0.4034 | IoU: 0.2570
#   Val   Loss: 0.7193 | Dice: 0.3946 | IoU: 0.2499
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 156/300
#   Train Loss: 0.7110 | Dice: 0.4119 | IoU: 0.2646
#   Val   Loss: 0.7566 | Dice: 0.3557 | IoU: 0.2223
# ------------------------------
# Epoch 157/300
#   Train Loss: 0.7046 | Dice: 0.4005 | IoU: 0.2545
#   Val   Loss: 0.7391 | Dice: 0.3773 | IoU: 0.2372
# ------------------------------
# Epoch 158/300
#   Train Loss: 0.6996 | Dice: 0.4030 | IoU: 0.2590
#   Val   Loss: 0.7310 | Dice: 0.3890 | IoU: 0.2461
# ------------------------------
# Epoch 159/300
#   Train Loss: 0.6951 | Dice: 0.4225 | IoU: 0.2719
#   Val   Loss: 0.7721 | Dice: 0.3635 | IoU: 0.2273
# ------------------------------
# Epoch 160/300
#   Train Loss: 0.6970 | Dice: 0.4132 | IoU: 0.2653
#   Val   Loss: 0.7236 | Dice: 0.4063 | IoU: 0.2587
# ------------------------------
# Epoch 161/300
#   Train Loss: 0.7016 | Dice: 0.4255 | IoU: 0.2744
#   Val   Loss: 0.7816 | Dice: 0.3268 | IoU: 0.2021
# ------------------------------
# Epoch 162/300
#   Train Loss: 0.7049 | Dice: 0.3987 | IoU: 0.2526
#   Val   Loss: 0.7304 | Dice: 0.4096 | IoU: 0.2601
# ------------------------------
# Epoch 163/300
#   Train Loss: 0.7003 | Dice: 0.4060 | IoU: 0.2593
#   Val   Loss: 0.7681 | Dice: 0.3874 | IoU: 0.2450
# ------------------------------
# Epoch 164/300
#   Train Loss: 0.6953 | Dice: 0.4309 | IoU: 0.2793
#   Val   Loss: 0.7537 | Dice: 0.3599 | IoU: 0.2242
# ------------------------------
# Epoch 165/300
#   Train Loss: 0.6917 | Dice: 0.4170 | IoU: 0.2678
#   Val   Loss: 0.7391 | Dice: 0.4072 | IoU: 0.2591
# ------------------------------
# Epoch 166/300
#   Train Loss: 0.6903 | Dice: 0.4360 | IoU: 0.2832
#   Val   Loss: 0.7595 | Dice: 0.3597 | IoU: 0.2250
# ------------------------------
# Epoch 167/300
#   Train Loss: 0.6923 | Dice: 0.4158 | IoU: 0.2660
#   Val   Loss: 0.7398 | Dice: 0.4066 | IoU: 0.2579
# ------------------------------
# Epoch 168/300
#   Train Loss: 0.6894 | Dice: 0.4318 | IoU: 0.2794
#   Val   Loss: 0.7268 | Dice: 0.4002 | IoU: 0.2540
# ------------------------------
# Epoch 169/300
#   Train Loss: 0.6825 | Dice: 0.4420 | IoU: 0.2871
#   Val   Loss: 0.7365 | Dice: 0.3902 | IoU: 0.2458
# ------------------------------
# Epoch 170/300
#   Train Loss: 0.6820 | Dice: 0.4221 | IoU: 0.2712
#   Val   Loss: 0.7255 | Dice: 0.4177 | IoU: 0.2654
# ------------------------------
# Epoch 171/300
#   Train Loss: 0.6778 | Dice: 0.4374 | IoU: 0.2831
#   Val   Loss: 0.7342 | Dice: 0.3956 | IoU: 0.2494
# ------------------------------
# Epoch 172/300
#   Train Loss: 0.6787 | Dice: 0.4455 | IoU: 0.2890
#   Val   Loss: 0.7463 | Dice: 0.3829 | IoU: 0.2397
# ------------------------------
# Epoch 173/300
#   Train Loss: 0.6759 | Dice: 0.4423 | IoU: 0.2872
#   Val   Loss: 0.7356 | Dice: 0.3954 | IoU: 0.2491
# ------------------------------
# Epoch 174/300
#   Train Loss: 0.6729 | Dice: 0.4258 | IoU: 0.2730
#   Val   Loss: 0.7554 | Dice: 0.4036 | IoU: 0.2566
# ------------------------------
# Epoch 175/300
#   Train Loss: 0.6876 | Dice: 0.4340 | IoU: 0.2822
#   Val   Loss: 0.7228 | Dice: 0.4168 | IoU: 0.2645
# ------------------------------
# Epoch 176/300
#   Train Loss: 0.6788 | Dice: 0.4377 | IoU: 0.2815
#   Val   Loss: 0.7244 | Dice: 0.4286 | IoU: 0.2747
# ------------------------------
# Epoch 177/300
#   Train Loss: 0.6754 | Dice: 0.4477 | IoU: 0.2915
#   Val   Loss: 0.7351 | Dice: 0.3973 | IoU: 0.2517
# ------------------------------
# Epoch 178/300
#   Train Loss: 0.6745 | Dice: 0.4499 | IoU: 0.2937
#   Val   Loss: 0.7325 | Dice: 0.3899 | IoU: 0.2460
# ------------------------------
# Epoch 179/300
#   Train Loss: 0.6706 | Dice: 0.4422 | IoU: 0.2871
#   Val   Loss: 0.7208 | Dice: 0.4148 | IoU: 0.2638
# ------------------------------
# Epoch 180/300
#   Train Loss: 0.6761 | Dice: 0.4152 | IoU: 0.2640
#   Val   Loss: 0.7528 | Dice: 0.4199 | IoU: 0.2667
# ------------------------------
# Epoch 181/300
#   Train Loss: 0.6753 | Dice: 0.4588 | IoU: 0.2998
#   Val   Loss: 0.7577 | Dice: 0.3841 | IoU: 0.2410
# ------------------------------
# Epoch 182/300
#   Train Loss: 0.6660 | Dice: 0.4563 | IoU: 0.2972
#   Val   Loss: 0.7309 | Dice: 0.4199 | IoU: 0.2678
# ------------------------------
# Epoch 183/300
#   Train Loss: 0.6602 | Dice: 0.4508 | IoU: 0.2940
#   Val   Loss: 0.7265 | Dice: 0.4215 | IoU: 0.2690
# ------------------------------
# Epoch 184/300
#   Train Loss: 0.6655 | Dice: 0.4547 | IoU: 0.2960
#   Val   Loss: 0.7424 | Dice: 0.4095 | IoU: 0.2607
# ------------------------------
# Epoch 185/300
#   Train Loss: 0.6698 | Dice: 0.4553 | IoU: 0.2983
#   Val   Loss: 0.7521 | Dice: 0.3802 | IoU: 0.2372
# ------------------------------
# Epoch 186/300
#   Train Loss: 0.6792 | Dice: 0.4241 | IoU: 0.2714
#   Val   Loss: 0.7322 | Dice: 0.4274 | IoU: 0.2741
# ------------------------------
# Epoch 187/300
#   Train Loss: 0.6596 | Dice: 0.4526 | IoU: 0.2953
#   Val   Loss: 0.7127 | Dice: 0.4392 | IoU: 0.2829
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 188/300
#   Train Loss: 0.6542 | Dice: 0.4690 | IoU: 0.3084
#   Val   Loss: 0.7373 | Dice: 0.4139 | IoU: 0.2637
# ------------------------------
# Epoch 189/300
#   Train Loss: 0.6490 | Dice: 0.4702 | IoU: 0.3095
#   Val   Loss: 0.7259 | Dice: 0.4335 | IoU: 0.2793
# ------------------------------
# Epoch 190/300
#   Train Loss: 0.6433 | Dice: 0.4647 | IoU: 0.3049
#   Val   Loss: 0.7245 | Dice: 0.4265 | IoU: 0.2735
# ------------------------------
# Epoch 191/300
#   Train Loss: 0.6432 | Dice: 0.4722 | IoU: 0.3111
#   Val   Loss: 0.7476 | Dice: 0.4126 | IoU: 0.2623
# ------------------------------
# Epoch 192/300
#   Train Loss: 0.6397 | Dice: 0.4744 | IoU: 0.3131
#   Val   Loss: 0.7223 | Dice: 0.4357 | IoU: 0.2809
# ------------------------------
# Epoch 193/300
#   Train Loss: 0.6346 | Dice: 0.4749 | IoU: 0.3134
#   Val   Loss: 0.7221 | Dice: 0.4408 | IoU: 0.2847
# ------------------------------
# Epoch 194/300
#   Train Loss: 0.6338 | Dice: 0.4817 | IoU: 0.3192
#   Val   Loss: 0.7151 | Dice: 0.4587 | IoU: 0.2983
# ------------------------------
# Epoch 195/300
#   Train Loss: 0.6405 | Dice: 0.4740 | IoU: 0.3125
#   Val   Loss: 0.7190 | Dice: 0.4545 | IoU: 0.2962
# ------------------------------
# Epoch 196/300
#   Train Loss: 0.6309 | Dice: 0.4975 | IoU: 0.3329
#   Val   Loss: 0.7210 | Dice: 0.4488 | IoU: 0.2914
# ------------------------------
# Epoch 197/300
#   Train Loss: 0.6249 | Dice: 0.4972 | IoU: 0.3329
#   Val   Loss: 0.7314 | Dice: 0.4474 | IoU: 0.2905
# ------------------------------
# Epoch 198/300
#   Train Loss: 0.6199 | Dice: 0.5022 | IoU: 0.3373
#   Val   Loss: 0.7559 | Dice: 0.4414 | IoU: 0.2863
# ------------------------------
# Epoch 199/300
#   Train Loss: 0.6210 | Dice: 0.4907 | IoU: 0.3275
#   Val   Loss: 0.7103 | Dice: 0.4616 | IoU: 0.3009
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 200/300
#   Train Loss: 0.6278 | Dice: 0.4904 | IoU: 0.3274
#   Val   Loss: 0.7208 | Dice: 0.4631 | IoU: 0.3038
# ------------------------------
# Epoch 201/300
#   Train Loss: 0.6262 | Dice: 0.5065 | IoU: 0.3412
#   Val   Loss: 0.7653 | Dice: 0.4244 | IoU: 0.2720
# ------------------------------
# Epoch 202/300
#   Train Loss: 0.6237 | Dice: 0.5052 | IoU: 0.3397
#   Val   Loss: 0.7693 | Dice: 0.4188 | IoU: 0.2680
# ------------------------------
# Epoch 203/300
#   Train Loss: 0.6295 | Dice: 0.4626 | IoU: 0.3032
#   Val   Loss: 0.7187 | Dice: 0.4671 | IoU: 0.3062
# ------------------------------
# Epoch 204/300
#   Train Loss: 0.6238 | Dice: 0.4954 | IoU: 0.3319
#   Val   Loss: 0.7057 | Dice: 0.4645 | IoU: 0.3046
# ✅ Nouveau meilleur modèle sauvegardé
# ------------------------------
# Epoch 205/300
#   Train Loss: 0.6224 | Dice: 0.5091 | IoU: 0.3433
#   Val   Loss: 0.7442 | Dice: 0.4366 | IoU: 0.2821
# ------------------------------
# Epoch 206/300
#   Train Loss: 0.6211 | Dice: 0.4960 | IoU: 0.3319
#   Val   Loss: 0.7172 | Dice: 0.4603 | IoU: 0.3006
# ------------------------------
# Epoch 207/300
#   Train Loss: 0.6063 | Dice: 0.5006 | IoU: 0.3362
#   Val   Loss: 0.7093 | Dice: 0.4661 | IoU: 0.3058
# ------------------------------
# Epoch 208/300
#   Train Loss: 0.6055 | Dice: 0.5094 | IoU: 0.3441
#   Val   Loss: 0.7277 | Dice: 0.4597 | IoU: 0.3011
# ------------------------------
# Epoch 209/300
#   Train Loss: 0.6014 | Dice: 0.5206 | IoU: 0.3537
#   Val   Loss: 0.7691 | Dice: 0.4368 | IoU: 0.2828
# ------------------------------
# Epoch 210/300
#   Train Loss: 0.6041 | Dice: 0.5028 | IoU: 0.3388
#   Val   Loss: 0.7113 | Dice: 0.4760 | IoU: 0.3135
# ------------------------------
# Epoch 211/300
#   Train Loss: 0.5974 | Dice: 0.5198 | IoU: 0.3535
#   Val   Loss: 0.7196 | Dice: 0.4687 | IoU: 0.3079
# ------------------------------
# Epoch 212/300
#   Train Loss: 0.6032 | Dice: 0.5172 | IoU: 0.3507
#   Val   Loss: 0.7531 | Dice: 0.4520 | IoU: 0.2954
# ------------------------------
# Epoch 213/300
#   Train Loss: 0.5934 | Dice: 0.5205 | IoU: 0.3543
#   Val   Loss: 0.7378 | Dice: 0.4652 | IoU: 0.3052
# ------------------------------
# Epoch 214/300
#   Train Loss: 0.5984 | Dice: 0.5114 | IoU: 0.3463
#   Val   Loss: 0.7194 | Dice: 0.4867 | IoU: 0.3237
# ------------------------------
# Epoch 215/300
#   Train Loss: 0.5959 | Dice: 0.5304 | IoU: 0.3643
#   Val   Loss: 0.7293 | Dice: 0.4599 | IoU: 0.3014
# ------------------------------
# Epoch 216/300
#   Train Loss: 0.5879 | Dice: 0.5269 | IoU: 0.3596
#   Val   Loss: 0.7545 | Dice: 0.4673 | IoU: 0.3068
# ------------------------------
# Epoch 217/300
#   Train Loss: 0.5829 | Dice: 0.5293 | IoU: 0.3625
#   Val   Loss: 0.7149 | Dice: 0.4777 | IoU: 0.3155
# ------------------------------
# Epoch 218/300
#   Train Loss: 0.5791 | Dice: 0.5333 | IoU: 0.3662
#   Val   Loss: 0.7634 | Dice: 0.4751 | IoU: 0.3139
# ------------------------------
# Epoch 219/300
#   Train Loss: 0.5727 | Dice: 0.5456 | IoU: 0.3773
#   Val   Loss: 0.7348 | Dice: 0.4675 | IoU: 0.3077
# ------------------------------
# Epoch 220/300
#   Train Loss: 0.5706 | Dice: 0.5489 | IoU: 0.3808
#   Val   Loss: 0.7738 | Dice: 0.4709 | IoU: 0.3113
# ------------------------------
# Epoch 221/300
#   Train Loss: 0.5643 | Dice: 0.5554 | IoU: 0.3871
#   Val   Loss: 0.7298 | Dice: 0.4829 | IoU: 0.3204
# ------------------------------
# Epoch 222/300
#   Train Loss: 0.5621 | Dice: 0.5426 | IoU: 0.3756
#   Val   Loss: 0.7391 | Dice: 0.4853 | IoU: 0.3231
# ------------------------------
# Epoch 223/300
#   Train Loss: 0.5492 | Dice: 0.5679 | IoU: 0.3992
#   Val   Loss: 0.7603 | Dice: 0.4782 | IoU: 0.3170
# ------------------------------
# Epoch 224/300
#   Train Loss: 0.5488 | Dice: 0.5646 | IoU: 0.3958
#   Val   Loss: 0.7624 | Dice: 0.4840 | IoU: 0.3211
# ------------------------------
# Epoch 225/300
#   Train Loss: 0.5477 | Dice: 0.5707 | IoU: 0.4020
#   Val   Loss: 0.7607 | Dice: 0.4885 | IoU: 0.3264
# ------------------------------
# Epoch 226/300
#   Train Loss: 0.5400 | Dice: 0.5780 | IoU: 0.4093
#   Val   Loss: 0.7734 | Dice: 0.4778 | IoU: 0.3170
# ------------------------------
# Epoch 227/300
#   Train Loss: 0.5421 | Dice: 0.5780 | IoU: 0.4091
#   Val   Loss: 0.7764 | Dice: 0.4834 | IoU: 0.3224
# ------------------------------
# Epoch 228/300
#   Train Loss: 0.5329 | Dice: 0.5847 | IoU: 0.4159
#   Val   Loss: 0.7855 | Dice: 0.4701 | IoU: 0.3115
# ------------------------------
# Epoch 229/300
#   Train Loss: 0.5447 | Dice: 0.5622 | IoU: 0.3940
#   Val   Loss: 0.8237 | Dice: 0.4671 | IoU: 0.3086
# ------------------------------
# Epoch 230/300
#   Train Loss: 0.5378 | Dice: 0.5889 | IoU: 0.4197
#   Val   Loss: 0.7572 | Dice: 0.4846 | IoU: 0.3236
# ------------------------------
# Epoch 231/300
#   Train Loss: 0.5391 | Dice: 0.5504 | IoU: 0.3831
#   Val   Loss: 0.7434 | Dice: 0.4913 | IoU: 0.3269
# ------------------------------
# Epoch 232/300
#   Train Loss: 0.5317 | Dice: 0.5775 | IoU: 0.4090
#   Val   Loss: 0.7565 | Dice: 0.4957 | IoU: 0.3320
# ------------------------------
# Epoch 233/300
#   Train Loss: 0.5276 | Dice: 0.6065 | IoU: 0.4376
#   Val   Loss: 0.8280 | Dice: 0.4647 | IoU: 0.3068
# ------------------------------
# Epoch 234/300
#   Train Loss: 0.5294 | Dice: 0.5666 | IoU: 0.3982
#   Val   Loss: 0.7591 | Dice: 0.4859 | IoU: 0.3223
# ------------------------------
# Epoch 235/300
#   Train Loss: 0.5377 | Dice: 0.5584 | IoU: 0.3900
#   Val   Loss: 0.7893 | Dice: 0.4842 | IoU: 0.3224
# ------------------------------
# Epoch 236/300
#   Train Loss: 0.5183 | Dice: 0.6092 | IoU: 0.4403
#   Val   Loss: 0.7576 | Dice: 0.4876 | IoU: 0.3253
# ------------------------------
# Epoch 237/300
#   Train Loss: 0.5168 | Dice: 0.5729 | IoU: 0.4047
#   Val   Loss: 0.7483 | Dice: 0.4999 | IoU: 0.3360
# ------------------------------
# Epoch 238/300
#   Train Loss: 0.5159 | Dice: 0.6044 | IoU: 0.4357
#   Val   Loss: 0.7853 | Dice: 0.4883 | IoU: 0.3267
# ------------------------------
# Epoch 239/300
#   Train Loss: 0.5030 | Dice: 0.6045 | IoU: 0.4360
#   Val   Loss: 0.7825 | Dice: 0.4902 | IoU: 0.3276
# ------------------------------
# Epoch 240/300
#   Train Loss: 0.4961 | Dice: 0.6086 | IoU: 0.4396
#   Val   Loss: 0.8105 | Dice: 0.4917 | IoU: 0.3287
# ------------------------------
# Epoch 241/300
#   Train Loss: 0.4921 | Dice: 0.6250 | IoU: 0.4566
#   Val   Loss: 0.7834 | Dice: 0.4984 | IoU: 0.3359
# ------------------------------
# Epoch 242/300
#   Train Loss: 0.4875 | Dice: 0.6104 | IoU: 0.4422
#   Val   Loss: 0.7848 | Dice: 0.4980 | IoU: 0.3344
# ------------------------------
# Epoch 243/300
#   Train Loss: 0.4833 | Dice: 0.6306 | IoU: 0.4628
#   Val   Loss: 0.8049 | Dice: 0.4983 | IoU: 0.3352
# ------------------------------
# Epoch 244/300
#   Train Loss: 0.4766 | Dice: 0.6370 | IoU: 0.4700
#   Val   Loss: 0.8105 | Dice: 0.4960 | IoU: 0.3332
# ------------------------------
# Epoch 245/300
#   Train Loss: 0.4742 | Dice: 0.6292 | IoU: 0.4615
#   Val   Loss: 0.7986 | Dice: 0.5003 | IoU: 0.3361
# ------------------------------
# Epoch 246/300
#   Train Loss: 0.4711 | Dice: 0.6282 | IoU: 0.4603
#   Val   Loss: 0.7980 | Dice: 0.4976 | IoU: 0.3336
# ------------------------------
# Epoch 247/300
#   Train Loss: 0.4649 | Dice: 0.6415 | IoU: 0.4748
#   Val   Loss: 0.8287 | Dice: 0.4982 | IoU: 0.3346
# ------------------------------
# Epoch 248/300
#   Train Loss: 0.4650 | Dice: 0.6507 | IoU: 0.4842
#   Val   Loss: 0.8150 | Dice: 0.4996 | IoU: 0.3358
# ------------------------------
# Epoch 249/300
#   Train Loss: 0.4633 | Dice: 0.6309 | IoU: 0.4638
#   Val   Loss: 0.8080 | Dice: 0.5020 | IoU: 0.3378
# ------------------------------
# Epoch 250/300
#   Train Loss: 0.4586 | Dice: 0.6575 | IoU: 0.4919
#   Val   Loss: 0.8393 | Dice: 0.4963 | IoU: 0.3331
# ------------------------------
# Epoch 251/300
#   Train Loss: 0.4534 | Dice: 0.6530 | IoU: 0.4869
#   Val   Loss: 0.8198 | Dice: 0.4980 | IoU: 0.3344
# ------------------------------
# Epoch 252/300
#   Train Loss: 0.4492 | Dice: 0.6518 | IoU: 0.4856
#   Val   Loss: 0.8260 | Dice: 0.5063 | IoU: 0.3415
# ------------------------------
# Epoch 253/300
#   Train Loss: 0.4460 | Dice: 0.6617 | IoU: 0.4966
#   Val   Loss: 0.8375 | Dice: 0.4962 | IoU: 0.3329
# ------------------------------
# Epoch 254/300
#   Train Loss: 0.4448 | Dice: 0.6597 | IoU: 0.4943
#   Val   Loss: 0.8442 | Dice: 0.5047 | IoU: 0.3403
# ------------------------------
# Epoch 255/300
#   Train Loss: 0.4392 | Dice: 0.6660 | IoU: 0.5010
#   Val   Loss: 0.8404 | Dice: 0.5012 | IoU: 0.3371
# ------------------------------
# Epoch 256/300
#   Train Loss: 0.4352 | Dice: 0.6690 | IoU: 0.5047
#   Val   Loss: 0.8439 | Dice: 0.5033 | IoU: 0.3389
# ------------------------------
# Epoch 257/300
#   Train Loss: 0.4296 | Dice: 0.6704 | IoU: 0.5060
#   Val   Loss: 0.8413 | Dice: 0.5053 | IoU: 0.3405
# ------------------------------
# Epoch 258/300
#   Train Loss: 0.4274 | Dice: 0.6758 | IoU: 0.5120
#   Val   Loss: 0.8507 | Dice: 0.5049 | IoU: 0.3404
# ------------------------------
# Epoch 259/300
#   Train Loss: 0.4245 | Dice: 0.6824 | IoU: 0.5196
#   Val   Loss: 0.8536 | Dice: 0.5034 | IoU: 0.3392
# ------------------------------
# Epoch 260/300
#   Train Loss: 0.4198 | Dice: 0.6771 | IoU: 0.5136
#   Val   Loss: 0.8572 | Dice: 0.5047 | IoU: 0.3400
# ------------------------------
# Epoch 261/300
#   Train Loss: 0.4193 | Dice: 0.6829 | IoU: 0.5203
#   Val   Loss: 0.8693 | Dice: 0.5025 | IoU: 0.3384
# ------------------------------
# Epoch 262/300
#   Train Loss: 0.4153 | Dice: 0.6811 | IoU: 0.5181
#   Val   Loss: 0.8625 | Dice: 0.5073 | IoU: 0.3424
# ------------------------------
# Epoch 263/300
#   Train Loss: 0.4121 | Dice: 0.6869 | IoU: 0.5247
#   Val   Loss: 0.8693 | Dice: 0.5069 | IoU: 0.3421
# ------------------------------
# Epoch 264/300
#   Train Loss: 0.4092 | Dice: 0.6912 | IoU: 0.5296
#   Val   Loss: 0.8772 | Dice: 0.5028 | IoU: 0.3385
# ------------------------------
# Epoch 265/300
#   Train Loss: 0.4075 | Dice: 0.6852 | IoU: 0.5227
#   Val   Loss: 0.8786 | Dice: 0.5078 | IoU: 0.3427
# ------------------------------
# Epoch 266/300
#   Train Loss: 0.4031 | Dice: 0.6945 | IoU: 0.5333
#   Val   Loss: 0.8860 | Dice: 0.5046 | IoU: 0.3401
# ------------------------------
# Epoch 267/300
#   Train Loss: 0.4035 | Dice: 0.6857 | IoU: 0.5232
#   Val   Loss: 0.8778 | Dice: 0.5075 | IoU: 0.3421
# ------------------------------
# Epoch 268/300
#   Train Loss: 0.4017 | Dice: 0.6963 | IoU: 0.5354
#   Val   Loss: 0.8952 | Dice: 0.5057 | IoU: 0.3410
# ------------------------------
# Epoch 269/300
#   Train Loss: 0.4010 | Dice: 0.6963 | IoU: 0.5353
#   Val   Loss: 0.8806 | Dice: 0.5104 | IoU: 0.3448
# ------------------------------
# Epoch 270/300
#   Train Loss: 0.3982 | Dice: 0.6968 | IoU: 0.5362
#   Val   Loss: 0.8821 | Dice: 0.5076 | IoU: 0.3430
# ------------------------------
# Epoch 271/300
#   Train Loss: 0.3965 | Dice: 0.6973 | IoU: 0.5366
#   Val   Loss: 0.8744 | Dice: 0.5125 | IoU: 0.3469
# ------------------------------
# Epoch 272/300
#   Train Loss: 0.3954 | Dice: 0.7004 | IoU: 0.5403
#   Val   Loss: 0.8881 | Dice: 0.5075 | IoU: 0.3425
# ------------------------------
# Epoch 273/300
#   Train Loss: 0.3923 | Dice: 0.6993 | IoU: 0.5389
#   Val   Loss: 0.8898 | Dice: 0.5129 | IoU: 0.3472
# ------------------------------
# Epoch 274/300
#   Train Loss: 0.3903 | Dice: 0.7072 | IoU: 0.5482
#   Val   Loss: 0.8912 | Dice: 0.5094 | IoU: 0.3442
# ------------------------------
# Epoch 275/300
#   Train Loss: 0.3902 | Dice: 0.7005 | IoU: 0.5403
#   Val   Loss: 0.8878 | Dice: 0.5100 | IoU: 0.3448
# ------------------------------
# Epoch 276/300
#   Train Loss: 0.3901 | Dice: 0.7054 | IoU: 0.5463
#   Val   Loss: 0.8942 | Dice: 0.5106 | IoU: 0.3454
# ------------------------------
# Epoch 277/300
#   Train Loss: 0.3873 | Dice: 0.7047 | IoU: 0.5451
#   Val   Loss: 0.8984 | Dice: 0.5093 | IoU: 0.3442
# ------------------------------
# Epoch 278/300
#   Train Loss: 0.3850 | Dice: 0.7071 | IoU: 0.5481
#   Val   Loss: 0.8968 | Dice: 0.5108 | IoU: 0.3453
# ------------------------------
# Epoch 279/300
#   Train Loss: 0.3855 | Dice: 0.7067 | IoU: 0.5477
#   Val   Loss: 0.9014 | Dice: 0.5089 | IoU: 0.3437
# ------------------------------
# Epoch 280/300
#   Train Loss: 0.3862 | Dice: 0.7026 | IoU: 0.5425
#   Val   Loss: 0.9016 | Dice: 0.5101 | IoU: 0.3448
# ------------------------------
# Epoch 281/300
#   Train Loss: 0.3836 | Dice: 0.7069 | IoU: 0.5478
#   Val   Loss: 0.9010 | Dice: 0.5107 | IoU: 0.3453
# ------------------------------
# Epoch 282/300
#   Train Loss: 0.3841 | Dice: 0.7076 | IoU: 0.5486
#   Val   Loss: 0.9051 | Dice: 0.5105 | IoU: 0.3451
# ------------------------------
# Epoch 283/300
#   Train Loss: 0.3827 | Dice: 0.7067 | IoU: 0.5475
#   Val   Loss: 0.9065 | Dice: 0.5110 | IoU: 0.3456
# ------------------------------
# Epoch 284/300
#   Train Loss: 0.3811 | Dice: 0.7095 | IoU: 0.5508
#   Val   Loss: 0.9049 | Dice: 0.5118 | IoU: 0.3463
# ------------------------------
# Epoch 285/300
#   Train Loss: 0.3828 | Dice: 0.7112 | IoU: 0.5529
#   Val   Loss: 0.9045 | Dice: 0.5119 | IoU: 0.3464
# ------------------------------
# Epoch 286/300
#   Train Loss: 0.3813 | Dice: 0.7107 | IoU: 0.5522
#   Val   Loss: 0.9047 | Dice: 0.5111 | IoU: 0.3457
# ------------------------------
# Epoch 287/300
#   Train Loss: 0.3807 | Dice: 0.7095 | IoU: 0.5508
#   Val   Loss: 0.9044 | Dice: 0.5111 | IoU: 0.3458
# ------------------------------
# Epoch 288/300
#   Train Loss: 0.3801 | Dice: 0.7094 | IoU: 0.5507
#   Val   Loss: 0.9041 | Dice: 0.5113 | IoU: 0.3459
# ------------------------------
# Epoch 289/300
#   Train Loss: 0.3799 | Dice: 0.7098 | IoU: 0.5513
#   Val   Loss: 0.9041 | Dice: 0.5116 | IoU: 0.3462
# ------------------------------
# Epoch 290/300
#   Train Loss: 0.3800 | Dice: 0.7107 | IoU: 0.5523
#   Val   Loss: 0.9048 | Dice: 0.5118 | IoU: 0.3464
# ------------------------------
# Epoch 291/300
#   Train Loss: 0.3788 | Dice: 0.7114 | IoU: 0.5532
#   Val   Loss: 0.9056 | Dice: 0.5120 | IoU: 0.3466
# ------------------------------
# Epoch 292/300
#   Train Loss: 0.3791 | Dice: 0.7118 | IoU: 0.5535
#   Val   Loss: 0.9058 | Dice: 0.5120 | IoU: 0.3466
# ------------------------------
# Epoch 293/300
#   Train Loss: 0.3791 | Dice: 0.7115 | IoU: 0.5532
#   Val   Loss: 0.9059 | Dice: 0.5118 | IoU: 0.3464
# ------------------------------
# Epoch 294/300
#   Train Loss: 0.3796 | Dice: 0.7111 | IoU: 0.5527
#   Val   Loss: 0.9058 | Dice: 0.5117 | IoU: 0.3463
# ------------------------------
# Epoch 295/300
#   Train Loss: 0.3783 | Dice: 0.7111 | IoU: 0.5527
#   Val   Loss: 0.9058 | Dice: 0.5118 | IoU: 0.3464
# ------------------------------
# Epoch 296/300
#   Train Loss: 0.3784 | Dice: 0.7112 | IoU: 0.5529
#   Val   Loss: 0.9057 | Dice: 0.5119 | IoU: 0.3464
# ------------------------------
# Epoch 297/300
#   Train Loss: 0.3789 | Dice: 0.7113 | IoU: 0.5530
#   Val   Loss: 0.9057 | Dice: 0.5119 | IoU: 0.3465
# ------------------------------
# Epoch 298/300
#   Train Loss: 0.3794 | Dice: 0.7114 | IoU: 0.5531
#   Val   Loss: 0.9057 | Dice: 0.5120 | IoU: 0.3465
# ------------------------------
# Epoch 299/300
#   Train Loss: 0.3787 | Dice: 0.7115 | IoU: 0.5532
#   Val   Loss: 0.9057 | Dice: 0.5120 | IoU: 0.3465
# ------------------------------
# Epoch 300/300
#   Train Loss: 0.3787 | Dice: 0.7115 | IoU: 0.5532
#   Val   Loss: 0.9057 | Dice: 0.5120 | IoU: 0.3465

# %%
with open(save_dir / "UNet_v3_300epoch_train_history.json", "w") as f:
    json.dump(train_history, f, indent=4)

with open(save_dir / "UNet_v3_300epoch__val_history.json", "w") as f:
    json.dump(val_history, f, indent=4)

print("Historiques sauvegardés en JSON")
# Out:
# Historiques sauvegardés en JSON

# %% [markdown]
# # Validation tests

# %% [markdown]
# #### Load the best model

# %%
model = torch.load(save_dir / "best_model_full.pth")
# Out:
# /tmp/ipykernel_1394080/1138156330.py:1: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model = torch.load(save_dir / "best_model_full.pth")

# %% [markdown]
# #### Images

# %%
model.eval()
total_correct = 0
total_pixels = 0

# 📁 Dossier pour sauvegarder les prédictions
pred_dir = save_dir / "predictions"
pred_dir.mkdir(parents=True, exist_ok=True)

with torch.no_grad():
    img_index = 0  # compteur global des images

    for imgs, masks in val_loader:
        imgs = imgs.to(device)
        masks = masks.to(device)

        outputs = model(imgs)
        preds = torch.argmax(F.softmax(outputs, dim=1), dim=1)

        # Boucle sur chaque image du batch
        for i in range(len(imgs)):
            pred = preds[i]
            mask = masks[i]

            # ===== Calcul de l’accuracy de cette image =====
            correct_pixels = (pred == mask).sum().item()
            total_pixels_img = mask.numel()
            acc_img = correct_pixels / total_pixels_img

            print(f"🖼️ Image {img_index+1} — Accuracy : {acc_img:.4f}")

            # ===== Création de la figure =====
            fig, ax = plt.subplots(1, 3, figsize=(10, 4))
            ax[0].imshow(imgs[i].cpu().permute(1, 2, 0))
            ax[0].set_title("Original picture")
            ax[1].imshow(mask.cpu(), cmap="gray")
            ax[1].set_title("Real mask")
            ax[2].imshow(pred.cpu(), cmap="gray")
            ax[2].set_title("Predicted mask")
            for a in ax:
                a.axis("off")
            plt.tight_layout()

            # 📌 Sauvegarde dans Models/<model_name>/predictions/
            save_path = pred_dir / f"val_img_{img_index:03d}.png"
            plt.savefig(save_path, dpi=150, bbox_inches='tight')

            # ✅ Affichage immédiat dans notebook
            plt.show()

            # ===== Accumulateur global =====
            total_correct += correct_pixels
            total_pixels += total_pixels_img
            img_index += 1

# ===== Accuracy globale =====
val_acc = total_correct / total_pixels
print(f"\n✅ Accuracy moyenne sur le jeu de validation : {val_acc:.4f}")
# Out:
# 🖼️ Image 1 — Accuracy : 0.9180
# 🖼️ Image 2 — Accuracy : 0.9171
# 🖼️ Image 3 — Accuracy : 0.8957
# 🖼️ Image 4 — Accuracy : 0.9047
# 🖼️ Image 5 — Accuracy : 0.8569
# ✅ Accuracy moyenne sur le jeu de validation : 0.8985

# %% [markdown]
# #### Curves

# %%
# --- Création du dossier d'enregistrement ---
curves_dir = save_dir / "curves"
curves_dir.mkdir(parents=True, exist_ok=True)

def plot_metric(train_history, val_history, key, title=None, mark_best_on="val_loss", save_folder=curves_dir):
    """
    key:        nom de la métrique dans les dicts (ex: "loss", "dice", "auc")
    mark_best_on:
        - "val_loss" → marquer l'epoch où val_loss est minimal
        - "val_<key>" → marquer la meilleure valeur de cette métrique (max)
    """

    train = train_history.get(key, [])
    val   = val_history.get(key, [])

    if len(val) == 0:
        print(f"⚠️ Impossible de tracer '{key}' (pas de valeurs validation trouvées)")
        return

    epochs = range(1, len(val)+1)

    plt.figure(figsize=(7,5))
    plt.plot(epochs, train, label=f"Train {key}", linewidth=2)
    plt.plot(epochs, val,   label=f"Val {key}", linewidth=2)

    # ========= Marqueur du "best" =========
    if mark_best_on == "val_loss" and "loss" in val_history:
        best_e = int(np.argmin(val_history["loss"])) + 1
        best_v = val[best_e-1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")
    elif mark_best_on == f"val_{key}" and len(val) > 0:
        best_e = int(np.nanargmax(val)) + 1
        best_v = val[best_e-1]
        plt.scatter([best_e], [best_v], s=80, marker="o", color="red", zorder=3,
                    label=f"best @ epoch {best_e}")

    plt.xlabel("Epoch")
    plt.ylabel(key)
    plt.title(title or f"{key} (train vs val)")
    plt.grid(True)
    plt.legend()

    # ========= SAVE =========
    save_path = save_folder / f"{key}.png"
    plt.savefig(save_path, dpi=200, bbox_inches="tight")
    print(f"💾 Courbe sauvegardée : {save_path}")

    plt.show()   # continue à afficher


# ======== TRAÇAGE ========

plot_metric(train_history, val_history, "loss", title="Loss curves", mark_best_on="val_loss")
plot_metric(train_history, val_history, "dice", title="Dice (artery+vein avg)", mark_best_on="val_dice")
plot_metric(train_history, val_history, "auc",  title="AUC (artery+vein avg)",  mark_best_on="val_auc")
# Out:
# 💾 Courbe sauvegardée : Models/My_UNet_v3_new_loss_300epochs/curves/loss.png
# 💾 Courbe sauvegardée : Models/My_UNet_v3_new_loss_300epochs/curves/dice.png
# 💾 Courbe sauvegardée : Models/My_UNet_v3_new_loss_300epochs/curves/auc.png

# %% [markdown]
# #### Summary of the metrics

# %%
# =========================
#   CONFIG CLASSES
# =========================
ARTERY_CLASS = 1
VEIN_CLASS   = 2
VESSEL_CLASSES = [ARTERY_CLASS, VEIN_CLASS]
assert NUM_CLASSES >= 3, "NUM_CLASSES doit inclure background + artery + vein"


# =========================
#  UTILS: métriques par classe
# =========================
def compute_per_class_metrics_from_confmat(sums, c):
    TP, FP, FN, TN = sums["TP"][c], sums["FP"][c], sums["FN"][c], sums["TN"][c]
    eps = 1e-7

    acc  = (TP + TN) / max(TP + TN + FP + FN, eps)
    prec = TP / max(TP + FP, eps)
    rec  = TP / max(TP + FN, eps)
    spec = TN / max(TN + FP, eps)
    dice = (2 * TP) / max(2 * TP + FP + FN, eps)
    iou  = TP / max(TP + FP + FN, eps)

    return {
        "accuracy":   float(acc),
        "precision":  float(prec),
        "recall":     float(rec),      # Sensitivity
        "specificity":float(spec),
        "dice":       float(dice),
        "iou":        float(iou),
    }

def compute_auc_for_class(buffers, c):
    pack = buffers.get(c, None)
    if pack is None or len(pack["y_true"]) == 0:
        return float("nan")

    y_true  = np.concatenate(pack["y_true"])
    y_score = np.concatenate(pack["y_score"])

    pos = (y_true == 1).sum()
    neg = (y_true == 0).sum()
    if pos == 0 or neg == 0:
        return float("nan")

    try:
        return float(roc_auc_score(y_true, y_score))
    except:
        return float("nan")


# =========================
#   ÉVALUATION
# =========================
model.eval()
conf_sums_val = init_confmat_sums(num_classes=NUM_CLASSES)
auc_buf_val   = init_auc_buffers(include_classes=VESSEL_CLASSES)

with torch.no_grad():
    for imgs, masks in val_loader:
        imgs  = imgs.to(device)
        masks = masks.to(device)

        outputs = model(imgs)
        preds = outputs.argmax(dim=1)

        update_confmat_sums(conf_sums_val, preds, masks, NUM_CLASSES)
        update_auc_buffers(auc_buf_val, outputs, masks)


# =========================
#   MÉTRIQUES PAR CLASSE
# =========================
results = {}

for cls, name in zip(VESSEL_CLASSES, ["Artery", "Vein"]):
    m = compute_per_class_metrics_from_confmat(conf_sums_val, cls)
    m["auc"] = compute_auc_for_class(auc_buf_val, cls)
    results[name] = m


# =========================
#   MOYENNES ARTERY + VEIN
# =========================
avg_metrics = {metric: np.nanmean([results["Artery"][metric], results["Vein"][metric]])
               for metric in results["Artery"].keys()}

results["Average (A+V)"] = avg_metrics


# =========================
#   AFFICHAGE TABLEAU (4 décimales)
# =========================
df = pd.DataFrame(results).T
df = df.round(4)  # <= Arrondi propre à 4 décimales

print("\n=== Résultats de validation ===\n")
display(df.style.format("{:.4f}"))
# Out:
# === Résultats de validation ===
# <style type="text/css">
# </style>
# <table id="T_37213">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37213_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_37213_level0_col1" class="col_heading level0 col1" >precision</th>
#       <th id="T_37213_level0_col2" class="col_heading level0 col2" >recall</th>
#       <th id="T_37213_level0_col3" class="col_heading level0 col3" >specificity</th>
#       <th id="T_37213_level0_col4" class="col_heading level0 col4" >dice</th>
#       <th id="T_37213_level0_col5" class="col_heading level0 col5" >iou</th>
#       <th id="T_37213_level0_col6" class="col_heading level0 col6" >auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37213_level0_row0" class="row_heading level0 row0" >Artery</th>
#       <td id="T_37213_row0_col0" class="data row0 col0" >0.9354</td>
#       <td id="T_37213_row0_col1" class="data row0 col1" >0.5226</td>
#       <td id="T_37213_row0_col2" class="data row0 col2" >0.6406</td>
#       <td id="T_37213_row0_col3" class="data row0 col3" >0.9570</td>
#       <td id="T_37213_row0_col4" class="data row0 col4" >0.5756</td>
#       <td id="T_37213_row0_col5" class="data row0 col5" >0.4041</td>
#       <td id="T_37213_row0_col6" class="data row0 col6" >0.9245</td>
#     </tr>
#     <tr>
#       <th id="T_37213_level0_row1" class="row_heading level0 row1" >Vein</th>
#       <td id="T_37213_row1_col0" class="data row1 col0" >0.9318</td>
#       <td id="T_37213_row1_col1" class="data row1 col1" >0.4284</td>
#       <td id="T_37213_row1_col2" class="data row1 col2" >0.4702</td>
#       <td id="T_37213_row1_col3" class="data row1 col3" >0.9607</td>
#       <td id="T_37213_row1_col4" class="data row1 col4" >0.4483</td>
#       <td id="T_37213_row1_col5" class="data row1 col5" >0.2889</td>
#       <td id="T_37213_row1_col6" class="data row1 col6" >0.7964</td>
#     </tr>
#     <tr>
#       <th id="T_37213_level0_row2" class="row_heading level0 row2" >Average (A+V)</th>
#       <td id="T_37213_row2_col0" class="data row2 col0" >0.9336</td>
#       <td id="T_37213_row2_col1" class="data row2 col1" >0.4755</td>
#       <td id="T_37213_row2_col2" class="data row2 col2" >0.5554</td>
#       <td id="T_37213_row2_col3" class="data row2 col3" >0.9589</td>
#       <td id="T_37213_row2_col4" class="data row2 col4" >0.5120</td>
#       <td id="T_37213_row2_col5" class="data row2 col5" >0.3465</td>
#       <td id="T_37213_row2_col6" class="data row2 col6" >0.8605</td>
#     </tr>
#   </tbody>
# </table>

# %%
# =========================
#   CONFIG CLASSES
# =========================
ARTERY_CLASS = 1
VEIN_CLASS   = 2
VESSEL_CLASSES = [ARTERY_CLASS, VEIN_CLASS]
assert NUM_CLASSES >= 3, "NUM_CLASSES must include background + artery + vein"

# =========================
#   PER-IMAGE METRIC HELPERS
# =========================
def dice_per_image(pred, target, cls):
    eps = 1e-7
    p = (pred == cls).float()
    t = (target == cls).float()
    inter = (p * t).sum()
    denom = p.sum() + t.sum()
    return float((2.0 * inter) / (denom + eps))

def iou_per_image(pred, target, cls):
    eps = 1e-7
    p = (pred == cls)
    t = (target == cls)
    inter = (p & t).sum().item()
    union = (p | t).sum().item()
    return float(inter / (union + eps))

def auc_per_image_from_logits(logits, target, cls):
    # logits: (C,H,W) for a single image
    probs = F.softmax(logits, dim=0)
    y_score = probs[cls].reshape(-1).cpu().numpy()
    y_true  = (target == cls).reshape(-1).cpu().numpy().astype(np.uint8)
    pos = (y_true == 1).sum()
    neg = (y_true == 0).sum()
    if pos == 0 or neg == 0:
        return float("nan")
    try:
        return float(roc_auc_score(y_true, y_score))
    except Exception:
        return float("nan")

# =========================
#   COLLECT PER-IMAGE METRICS
# =========================
model.eval()

artery_dice_list, vein_dice_list, avg_dice_list = [], [], []
artery_iou_list,  vein_iou_list,  avg_iou_list  = [], [], []
artery_auc_list,  vein_auc_list,  avg_auc_list  = [], [], []

with torch.no_grad():
    for imgs, masks in val_loader:
        imgs  = imgs.to(device)
        masks = masks.to(device)

        logits = model(imgs)          # (N,C,H,W)
        preds  = logits.argmax(dim=1) # (N,H,W)

        for i in range(imgs.size(0)):
            p   = preds[i]
            gt  = masks[i]
            log = logits[i]

            # Dice
            a_d = dice_per_image(p, gt, ARTERY_CLASS)
            v_d = dice_per_image(p, gt, VEIN_CLASS)
            artery_dice_list.append(a_d)
            vein_dice_list.append(v_d)
            avg_dice_list.append(np.nanmean([a_d, v_d]))

            # IoU
            a_i = iou_per_image(p, gt, ARTERY_CLASS)
            v_i = iou_per_image(p, gt, VEIN_CLASS)
            artery_iou_list.append(a_i)
            vein_iou_list.append(v_i)
            avg_iou_list.append(np.nanmean([a_i, v_i]))

            # AUC
            a_auc = auc_per_image_from_logits(log, gt, ARTERY_CLASS)
            v_auc = auc_per_image_from_logits(log, gt, VEIN_CLASS)
            artery_auc_list.append(a_auc)
            vein_auc_list.append(v_auc)
            avg_auc_list.append(np.nanmean([a_auc, v_auc]))

# =========================
#   BAR PLOTS (3 rows × 3 cols)
#   One bar per image; red dashed = mean
# =========================
def plot_bars_one_metric(ax, values, title):
    values = np.array(values, dtype=float)
    n = len(values)
    x = np.arange(1, n+1)

    ax.bar(x, values, color="steelblue", edgecolor="black", alpha=0.85)
    m = np.nanmean(values)
    ax.axhline(m, color="red", linestyle="--", linewidth=2, label=f"mean = {m:.3f}")

    ax.set_ylim(0, 1)            # metrics in [0,1]
    ax.set_xlim(0.5, n + 0.5)
    ax.set_xlabel("Validation image index")
    ax.set_ylabel("Score")
    ax.set_title(title)
    # lighten x ticks if many images
    if n > 30:
        ax.set_xticks(np.linspace(1, n, 10, dtype=int))
    ax.grid(axis="y", alpha=0.3)
    ax.legend(loc="upper right")

fig, axes = plt.subplots(3, 3, figsize=(20, 12), constrained_layout=True)

# Row 1: Dice
plot_bars_one_metric(axes[0,0], artery_dice_list, "Dice – Artery")
plot_bars_one_metric(axes[0,1], vein_dice_list,   "Dice – Vein")
plot_bars_one_metric(axes[0,2], avg_dice_list,    "Dice – Average (A+V)")

# Row 2: IoU
plot_bars_one_metric(axes[1,0], artery_iou_list, "IoU – Artery")
plot_bars_one_metric(axes[1,1], vein_iou_list,   "IoU – Vein")
plot_bars_one_metric(axes[1,2], avg_iou_list,    "IoU – Average (A+V)")

# Row 3: AUC
plot_bars_one_metric(axes[2,0], artery_auc_list, "AUC – Artery")
plot_bars_one_metric(axes[2,1], vein_auc_list,   "AUC – Vein")
plot_bars_one_metric(axes[2,2], avg_auc_list,    "AUC – Average (A+V)")

plt.show()
